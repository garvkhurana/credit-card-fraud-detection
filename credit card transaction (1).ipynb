# %%
import pandas as pd
dataset=pd.read_csv(r"C:\Users\Garv Khurana\OneDrive\Desktop\creditcard.csv")

# %%
dataset
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
dataset.isna().values.any()
# Out:
# False

# %%
dataset.isnull().values.any()
# Out:
# False

# %%
dataset.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
dataset["Class"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
#unbalanced data
dataset["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
Df=pd.value_counts(dataset["Class"],sort=True)
Df.plot(kind='bar')
# Out:
# <Axes: xlabel='Class'>

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.scatterplot(x=dataset["Time"],y=dataset["Amount"])
# Out:
# <Axes: xlabel='Time', ylabel='Amount'>

# %%
sns.boxplot(dataset)
# Out:
# <Axes: >

# %%
legit=dataset[dataset.Class==0]
fraud=dataset[dataset.Class==1]

# %%
legit
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
fraud
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
legit.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean    94838.202258       0.008258      -0.006271       0.012171
# std     47484.015786       1.929814       1.636146       1.459429
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54230.000000      -0.917544      -0.599473      -0.884541
# 50%     84711.000000       0.020023       0.064070       0.182158
# 75%    139333.000000       1.316218       0.800446       1.028372
# max    172792.000000       2.454930      18.902453       9.382558
#
#                   V4             V5             V6             V7  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean       -0.007860       0.005453       0.002419       0.009637
# std         1.399333       1.356952       1.329913       1.178812
# min        -5.683171    -113.743307     -26.160506     -31.764946
# ...

# %%
fraud.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     492.000000  492.000000  492.000000  492.000000  492.000000
# mean    80746.806911   -4.771948    3.623778   -7.033281    4.542029
# std     47835.365138    6.783687    4.291216    7.110937    2.873318
# min       406.000000  -30.552380   -8.402154  -31.103685   -1.313275
# 25%     41241.500000   -6.036063    1.188226   -8.643489    2.373050
# 50%     75568.500000   -2.342497    2.717869   -5.075257    4.177147
# 75%    128483.000000   -0.419200    4.971257   -2.276185    6.348729
# max    170348.000000    2.132386   22.057729    2.250210   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000  ...
# mean    -3.151225   -1.397737   -5.568731    0.570636   -2.581123  ...
# std      5.372468    1.858124    7.206773    6.797831    2.500896  ...
# ...

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %% [markdown]
# in this what we gonna do we are gonna take random 492 points of legit points and then we will join that data points with the fraud ones and then make an another dataset

# %%
legit_sample=legit.sample(n=492)

# %% [markdown]
# what .sample method will do it will randomly pick up 492 random values from the legit dataset where we have assigned n=492

# %%
legit_sample
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 223477  143401.0 -0.670923  0.702907  0.973256 -0.934647 -0.268419 -0.044683
# 47924    43417.0 -3.696609 -4.360481 -0.058937 -2.988076 -1.863844  0.727024
# 217519  140921.0  2.056532 -1.828513 -0.907668 -1.540565 -1.503170 -0.450492
# 34888    37871.0  1.233767 -0.261094  0.625359  0.487630 -0.235728  0.965769
# 38667    39488.0 -0.760492  0.559178  1.373329 -0.265319  0.809507  1.106188
# ...          ...       ...       ...       ...       ...       ...       ...
# 145682   87128.0  1.925939 -0.517349 -0.446796  0.442888 -0.797211 -0.705539
# 2742      2279.0 -1.055962  0.843840  1.568174 -0.011194  0.422437  1.382765
# 207147  136539.0 -1.149908  1.588097  0.448899 -1.057643  0.307357  0.310040
# 265207  161784.0  2.215465 -0.549719 -1.479905 -0.616898 -0.151175 -0.671694
# 277630  167763.0 -0.730770  0.872856 -2.062398 -1.458785  3.333398  3.170415
#
# ...

# %% [markdown]
# now we have merged two dataframes 1-random values from the legit dataset and
# 2-fraud values and we have set axis=0 that will merge the fraud values behind the legit ones

# %%
df=pd.concat([legit_sample,fraud],axis=0)
df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 223477  143401.0 -0.670923  0.702907  0.973256 -0.934647 -0.268419 -0.044683
# 47924    43417.0 -3.696609 -4.360481 -0.058937 -2.988076 -1.863844  0.727024
# 217519  140921.0  2.056532 -1.828513 -0.907668 -1.540565 -1.503170 -0.450492
# 34888    37871.0  1.233767 -0.261094  0.625359  0.487630 -0.235728  0.965769
# 38667    39488.0 -0.760492  0.559178  1.373329 -0.265319  0.809507  1.106188
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 223477  143401.0 -0.670923  0.702907  0.973256 -0.934647 -0.268419 -0.044683
# 47924    43417.0 -3.696609 -4.360481 -0.058937 -2.988076 -1.863844  0.727024
# 217519  140921.0  2.056532 -1.828513 -0.907668 -1.540565 -1.503170 -0.450492
# 34888    37871.0  1.233767 -0.261094  0.625359  0.487630 -0.235728  0.965769
# 38667    39488.0 -0.760492  0.559178  1.373329 -0.265319  0.809507  1.106188
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
x=df.drop(columns="Class")
y=df["Class"]
print(x)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 223477  143401.0 -0.670923  0.702907  0.973256 -0.934647 -0.268419 -0.044683
# 47924    43417.0 -3.696609 -4.360481 -0.058937 -2.988076 -1.863844  0.727024
# 217519  140921.0  2.056532 -1.828513 -0.907668 -1.540565 -1.503170 -0.450492
# 34888    37871.0  1.233767 -0.261094  0.625359  0.487630 -0.235728  0.965769
# 38667    39488.0 -0.760492  0.559178  1.373329 -0.265319  0.809507  1.106188
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
y
# Out:
# 223477    0
# 47924     0
# 217519    0
# 34888     0
# 38667     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,_train,y_test=train_test_split(x,y,test_size=0.30,random_state=50)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
ss.fit_transfrom(x_train)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
lr=LogisticRegression()
lr.fit(x_train,y_train)
predict=lr.predict(x_test)
accuracy_score(predict,y_test)
# Out:
# 0.9324324324324325

# %%
from sklearn.linear_model import Perceptron
p=Perceptron()
p.fit(x_train,y_train)
predict_of_p=p.predict(x_test)
accuracy_score(predict_of_p,y_test)
# Out:
# 0.48986486486486486

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
predict_of_knn=knn.predict(x_test)
accuracy_score(predict_of_knn,y_test)
# Out:
# 0.6418918918918919

# %%
from sklearn.svm import SVC
s=SVC(kernel='linear')
s.fit(x_train,y_train)
predict_of_s=s.predict(x_test)
accuracy_score(predict_of_s,y_test)
# Out:
# 0.9121621621621622

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(x_train,y_train)
predict_of_nb=nb.predict(x_test)
accuracy_score(predict_of_nb,y_test)
# Out:
# 0.875
